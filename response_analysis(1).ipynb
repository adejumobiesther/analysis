# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
#read in the data
data = pd.read_csv('/content/drive/My Drive/response.csv')

# %%
data.head()
# Out:
#   Country  Total_Cases New_Cases  ... Total_Tests    Tests     Continents
# 0   World      9067824    28,887  ...         NaN      NaN            All
# 1     USA      2356715        58  ...  28,492,770   86,093  North America
# 2  Brazil      1086990       NaN  ...   2,430,347   11,436  South America
# 3  Russia       592280     7,600  ...  17,200,000  117,862         Europe
# 4   India       426910       NaN  ...   6,950,493    5,038           Asia
#
# [5 rows x 13 columns]

# %%
#The number of rows and column in the data
data.shape
# Out:
# (216, 13)

# %%
data.dtypes
# Out:
# Country              object
# Total_Cases           int64
# New_Cases            object
# Total_Deaths         object
# New_Deaths           object
# Total_Recovered     float64
# Active_Cases        float64
# Serious/Critical    float64
# Tot_Cases            object
# Deaths               object
# Total_Tests          object
# Tests                object
# Continents           object
# dtype: object

# %%
#Using the argument 'all' to be able to view both categorical and numerical data
data.describe(include = 'all')
# Out:
#        Country   Total_Cases New_Cases  ... Total_Tests  Tests  Continents
# count      216  2.160000e+02        47  ...         191    191         214
# unique     216           NaN        37  ...         191    190           7
# top      Gabon           NaN         1  ...     569,589  5,038      Africa
# freq         1           NaN         4  ...           1      2          57
# mean       NaN  8.396133e+04       NaN  ...         NaN    NaN         NaN
# std        NaN  6.421554e+05       NaN  ...         NaN    NaN         NaN
# min        NaN  1.000000e+00       NaN  ...         NaN    NaN         NaN
# 25%        NaN  2.302500e+02       NaN  ...         NaN    NaN         NaN
# 50%        NaN  1.823000e+03       NaN  ...         NaN    NaN         NaN
# 75%        NaN  1.498525e+04       NaN  ...         NaN    NaN         NaN
# max        NaN  9.067824e+06       NaN  ...         NaN    NaN         NaN
#
# [11 rows x 13 columns]

# %%
data.groupby('Continents')['Country'].count()
# Out:
# Continents
# Africa               57
# All                   1
# Asia                 49
# Australia/Oceania     6
# Europe               48
# North America        39
# South America        14
# Name: Country, dtype: int64

# %%
#Columns that contain missing_values
missing_col = [col for col in data.columns if data[col].isnull().any()]
missing_col
# Out:
# ['New_Cases',
#  'New_Deaths',
#  'Total_Recovered',
#  'Active_Cases',
#  'Serious/Critical',
#  'Tot_Cases',
#  'Deaths',
#  'Total_Tests',
#  'Tests',
#  'Continents']

# %%
#Number of values missing in each column
n_values_missing = [data[val].isnull().sum() for val in missing_col] 
n_values_missing
# Out:
# [169, 194, 5, 4, 84, 2, 32, 25, 25, 2]

# %% [markdown]
# # **Cleaning the data:**

# %%
data.drop(['New_Cases', 'New_Deaths'], axis = 1, inplace = True)

# %%
#grouping countries and continents together
country_continents = dict(data.groupby('Country')['Continents'].count())

# %%
#checking for countries that do not have continent in the data
missing = [key for key,value in country_continents.items() if value == 0]
missing
# Out:
# ['Diamond Princess', 'MS Zaandam']

# %%
data['Continents'] = data['Continents'].fillna('Cruise_ships')

# %%
def fill_numerical_col(df, col):
  return df[col].fillna(0)

# %%
for col in data.columns:
  if data[col].dtype == 'float64':
    data[col] = fill_numerical_col(data, col)

# %%
data.describe()
# Out:
#         Total_Cases  Total_Recovered  Active_Cases  Serious/Critical
# count  2.160000e+02     2.160000e+02  2.160000e+02        216.000000
# mean   8.396133e+04     4.396105e+04  3.276278e+04        506.851852
# std    6.421554e+05     3.398558e+05  2.704153e+05       3971.904246
# min    1.000000e+00     0.000000e+00  0.000000e+00          0.000000
# 25%    2.302500e+02     1.082500e+02  2.050000e+01          0.000000
# 50%    1.823000e+03     8.870000e+02  4.025000e+02          2.000000
# 75%    1.498525e+04     8.147750e+03  4.001750e+03         18.250000
# max    9.067824e+06     4.850718e+06  3.746066e+06      54740.000000

# %%
def fill_categorical_data(df,col):
  return df[col].fillna(0)

# %%
for col in data.columns:
  if data[col].dtype == 'object':
    data[col] = fill_categorical_data(data,col)

# %%
data.describe(include = 'all')
# Out:
#        Country   Total_Cases Total_Deaths  ...  Total_Tests  Tests  Continents
# count      216  2.160000e+02          216  ...        216.0  216.0         216
# unique     216           NaN          132  ...        192.0  191.0           8
# top      Gabon           NaN               ...          0.0    0.0      Africa
# freq         1           NaN           30  ...         25.0   25.0          57
# mean       NaN  8.396133e+04          NaN  ...          NaN    NaN         NaN
# std        NaN  6.421554e+05          NaN  ...          NaN    NaN         NaN
# min        NaN  1.000000e+00          NaN  ...          NaN    NaN         NaN
# 25%        NaN  2.302500e+02          NaN  ...          NaN    NaN         NaN
# 50%        NaN  1.823000e+03          NaN  ...          NaN    NaN         NaN
# 75%        NaN  1.498525e+04          NaN  ...          NaN    NaN         NaN
# max        NaN  9.067824e+06          NaN  ...          NaN    NaN         NaN
#
# [11 rows x 11 columns]

# %% [markdown]
# # **Visualizing the data:**

# %%
plt.figure(figsize = (10,40))
sns.barplot(x=data['Total_Cases'], y = data['Country'] )
plt.xlabel('Total_Cases')
plt.ylabel('Country')
# Out:
# Text(0, 0.5, 'Country')

# %%
plt.figure(figsize = (10,40))
sns.barplot(x=data['Serious/Critical'], y = data['Country'] )
plt.xlabel('Serious/Critical')
plt.ylabel('Country')
# Out:
# Text(0, 0.5, 'Country')

# %%
plt.figure(figsize = (10,40))
sns.barplot(x=data['Active_Cases'], y = data['Country'] )
plt.xlabel('Active_Cases')
plt.ylabel('Country')
# Out:
# Text(0, 0.5, 'Country')

# %%
plt.figure(figsize = (10,40))
sns.barplot(x=data['Total_Recovered'], y = data['Country'])
plt.xlabel('Total_Recovered')
plt.ylabel('Country')
# Out:
# Text(0, 0.5, 'Country')

# %%
#The Total_Deaths column has numeric values inputed has strings and it contains empty string, replacing with a zero string
data['Total_Deaths'] = data['Total_Deaths'].str.replace(' ','0')

# %%
#Removing commas from numbers in the column
data['Total_Deaths'] = data['Total_Deaths'].str.replace(',', '')

# %%
#Changing the data_type of the column to float
data['Total_Deaths'] = data['Total_Deaths'].astype(float)

# %%
#Round down
data['Total_Deaths'] = data['Total_Deaths'].apply(np.floor)

# %%
#Changing the value of world's total death to zero
data.at[0, 'Total_Deaths'] = 0

# %%
#Summing up total deaths in all the countries
T = data['Total_Deaths'].sum()

# %%
#Changing the value of world's total death to the sum of total deaths in all countries
data.at[0, 'Total_Deaths'] = T

# %%
plt.figure(figsize = (10,40))
sns.barplot(x = data['Total_Deaths'], y = data['Country'])
plt.xlabel('Total_Deaths')
plt.ylabel('Country')
# Out:
# Text(0, 0.5, 'Country')

# %%
#Removing commas from the column
data['Total_Tests'] = data['Total_Tests'].str.replace(',', '')

# %%
data['Total_Tests'] = data['Total_Tests'].astype(float)

# %%
data['Total_Tests'] = data['Total_Tests'].apply(np.floor)

# %%
#Summing up total tests in all the countries
T = data['Total_Tests'].sum()

# %%
#Replacing world's total test with the sum of tests done in all countries
data.at[0, 'Total_Tests'] = T

# %%
plt.figure(figsize = (10,40))
sns.barplot(x = data['Total_Tests'], y = data['Country'])
plt.xlabel('Total_Tests')
plt.ylabel('Country')
# Out:
# Text(0, 0.5, 'Country')

# %%
c_data = data.sort_values('Total_Cases', ascending = False).reset_index()

# %%
#countries with highest number of cases
plt.figure(figsize = (10,5))
sns.barplot(x =c_data['Total_Cases'].sort_values(ascending = False).head(10), y = c_data['Country'].head(10))

# %%
n_data = data.sort_values('Serious/Critical', ascending= False).reset_index()

# %%
#Countries with highest number of serious or critical cases
plt.figure(figsize = (10,5))
sns.barplot(x = n_data['Serious/Critical'].head(10), y = n_data['Country'].head(10))

# %%
t_data = data.sort_values('Total_Recovered', ascending= False).reset_index()

# %%
#Countries with the highest rate of recovery
plt.figure(figsize = (10,5))
sns.barplot(x = t_data['Total_Recovered'].head(10), y = t_data['Country'].head(10))

# %%
d_data = data.sort_values('Total_Deaths', ascending= False).reset_index()

# %%
#Countries with the highest mortality rate
plt.figure(figsize = (10,5))
sns.barplot(x = d_data['Total_Deaths'].head(10), y = d_data['Country'].head(10))

# %%
plt.figure(figsize = (12,4))
sns.countplot(data['Continents'])
